# %%
'''
Create a program that will call a function to generate KE billing details
on the basis of given inputs.
The functions will only call other functions for any processing and only
print return values from calling function.

def bill_main(monthly_units):
    electric_charges=electricity(monthly_units)
    print("electric charges for ", monthly_units, " = ", electric_charges)
    
    uniform_charges=uniform(monthly_units)
    print("electric charges for ", monthly_units, " = ", fuel_charges)
    
    sales_tax=sales_tax(monthly_units)
    print("electric charges for ", monthly_units, " = ", sales_tax)
    
    advance_tax=advance_tax(monthly_units)
    print("electric charges for ", monthly_units, " = ", advance_tax)
    
    tv_fee=tv_fee(monthly_units)
    print("electric charges for ", monthly_units, " = ", "tv_fee")
    
    total=total(electric_charges, uniform_charges, fuel_charges, sales_tax, advance_tax, tv_fee)
    print("electric charges for ", monthly_units, " = ", total)
    
'''

# %%
def electricity(monthly_units):
    charges = 0
    if monthly_home_units > 1 and monthly_home_units <= 100:
        charges = monthly_home_units * 10.875
    elif monthly_home_units > 101 and monthly_home_units <= 200:
        charges = monthly_home_units * 20.875
    elif monthly_home_units > 201 and monthly_home_units <= 300:
        charges = monthly_home_units * 40.875
    elif monthly_home_units > 301 and monthly_home_units <= 400:
        charges = monthly_home_units * 80.875
    elif monthly_home_units > 401 and monthly_home_units <= 500:
        charges = monthly_home_units * 140.875
    elif monthly_home_units > 501 and monthly_home_units <= 600:
        charges = monthly_home_units * 240.875
    elif monthly_home_units > 601 and monthly_home_units <= 700:
        charges = monthly_home_units * 300.875
    elif monthly_home_units > 700:
        charges = monthly_home_units * 350.875
    else:
        charges = -1

    return charges
    
def uniform_charges(monthly_home_units):
    charges = monthly_home_units * 3.875
    return charges
    
# def fuel_charges():
# def sales():
# def advance():
# def tv_fees():

def bill_main(monthly_home_units):
    electric_charges = electricity(monthly_home_units)
    print("Electric charges for ",monthly_home_units,"Units =",electric_charges)
    
    uniform_charge = uniform_charges(monthly_home_units)
    print("Uniform  charges for ",monthly_home_units,"Units =",uniform_charge)
    
    #fuel_charges = fuel(monthly_home_units)
    #print("Electric charges for ",monthly_home_units," =",fuel_charges)
    
    #sales_tax = sales(monthly_home_units)
    #print("Electric charges for ",monthly_home_units," =",sales_tax)
    
    #advance_tax = advance(monthly_home_units)
    #print("Electric charges for ",monthly_home_units," =",advance_tax)
    
    #tv_fee = tv_fees(monthly_home_units)
    #print("Electric charges for ",monthly_home_units," =",tv_fee)
    
    #total = total(electric_charges, uniform_charges, fuel_charges, sales_tax, advance_tax, tv_fee)
    #print("Electric charges for ",monthly_home_units," =",total)

monthly_home_units = int(input("Enter Monthly Home Units: "))
# bill_main(525)
# bill_main(112)
# bill_main(349)
# bill_main(700)
# bill_main(-22)
# bill_main(450)
# bill_main(116)
bill_main(monthly_home_units)
# Out:
# Enter Monthly Home Units: 637
# Electric charges for  637 Units = 191657.375
# Uniform  charges for  637 Units = 2468.375
